# %%
# !pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\anita\miniconda3\envs\fbd\lib\site-packages (0.5.1)

# %%
import numpy as np
import os
from time import time
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import seaborn as sns
import ipynb
sns.set(style="darkgrid")
import warnings
#warnings.simplefilter(action='ignore', category=IntegrationWarning)

# %%
from ipynb.fs.full.closed_form_solution import f, p, p1, p2, call_price

# %%
start = time()

# Set the parameters
sigma = 0.61
theta = 0.019
kappa = 6.21
mu = 0.5
rho = -0.5
generator = np.random.default_rng()

n = [250, 400] # n time periods
m = [x**2 for x in n] # number of simulations

# %%
K = [1.5, 2.5]
S0 = [2, 3]
V0 = [0.01, 0.07]
int_rates = [0, 0.05]
time_maturity = [1, 2, 5]

# %% [markdown]
# Stock prices simulation:

# %%
def stock_price_generator (T, n ,m, r, S0, k, V0, sigma, theta, kappa, rho, generator):
    dt = T / n
    
    # Brownian motions:
    dw_v = generator.normal(size=(m, n)) * np.sqrt(dt)
    dw_i = generator.normal(size=(m, n)) * np.sqrt(dt)
    #dw_v = np.random.normal(size=(m, n)) * np.sqrt(dt)
    #dw_i = np.random.normal(size=(m, n)) * np.sqrt(dt)

    dw_s = rho * dw_v + np.sqrt(1.0 - rho ** 2) * dw_i

    # Perform time evolution 
    s = np.empty((m, n + 1)) # initialisation stock prices vector
    s[:, 0] = S0

    v = np.ones(m) * V0

    for t in range(n):
        dv = kappa * (theta - v) * dt + sigma * np.sqrt(v) * dw_v[:, t]
        ds = r * s[:, t] * dt + np.sqrt(v) * s[:, t] * dw_s[:, t]

        v = np.clip(v + dv, a_min=0.0, a_max=None)
        s[:, t + 1] = s[:, t] + ds
        
        
    return s

# %%
#s = stock_price_generator (, n ,m, r, S0, k, V0, sigma, theta, kappa, rho)

# %% [markdown]
# Plots stock prices simulations:

# %%
#plot_mc (s,,n)

# %% [markdown]
# Payoff:

# %%
# function which finds the expected payoff 
def find_expected_payoff(stock_paths, k, r, T):
    final = stock_paths - k
    payoff = [max(x,0) for x in final] # one payoff for each simulation
    payoff = np.asarray(payoff)
    expected_payoff = payoff.mean()
    c = expected_payoff * np.exp(-r * T)     # in case r=0, this step is useless
    
    return c

# %%
#c = find_expected_payoff(s, k, r, ) # in case r=0, this step is useless
#c

# %%
df = pd.DataFrame(columns=['S0', 'K', 'V0', 'T', 'r', 'n', 'm', 'closed_solution', 'mc_price', 'ST'])

# %%
s0 = S0[0]
for k in K:
        print(f'k {k}')
        for v0 in V0:
            print(f'v0 {v0}')
            for t in time_maturity:
                print(f't {t}')
                
                for r in int_rates:
                    # analytical closed sol
                    sol = call_price(kappa, theta, sigma, rho, v0, r, t, s0 ,k)

                    for i in range(len(n)):
                        nn = n[i]
                        mm = m[i]

                        # monte carlo solution:
                        s = stock_price_generator(t, nn, mm, r, s0, k, v0, sigma, theta, kappa, rho, generator) # stock prices of mc simulation
                        ST = s[:,-1]

                        if i==0:
                            if v0==0.01 and t==1:
                                stock_v01_1 = s
                            elif v0==0.01 and t==5:
                                stock_v01_5 = s
                            elif v0==0.07 and t==1:
                                stock_v07_1 = s
                            elif v0==0.07 and t==5:
                                stock_v07_5 = s

                        mc_price = find_expected_payoff(ST, k, r, t)

                        new_row = {'S0':s0, 'K':k, 'V0':v0, 'T':t, 'V0': v0, 'r':r, 'n':nn, 'm':mm, 'closed_solution':sol, 'mc_price':mc_price, 'ST':ST}
                        #append row to the dataframe
                        df = df.append(new_row, ignore_index=True)

# %%
s0 = S0[1]
for k in K:
        for v0 in V0:
            for t in time_maturity:
                
                for r in int_rates:
                    # analytical closed sol
                    sol = call_price(kappa, theta, sigma, rho, v0, r, t, s0 ,k)

                    for i in range(len(n)):
                        nn = n[i]
                        mm = m[i]

                        # monte carlo solution:
                        s = stock_price_generator(t, nn, mm, r, s0, k, v0, sigma, theta, kappa, rho, generator) # stock prices of mc simulation
                        ST = s[:,-1]

                        if i==0:
                            if v0==0.01 and t==1:
                                stock_v01_1 = s
                            elif v0==0.01 and t==5:
                                stock_v01_5 = s
                            elif v0==0.07 and t==1:
                                stock_v07_1 = s
                            elif v0==0.07 and t==5:
                                stock_v07_5 = s

                        mc_price = find_expected_payoff(ST, k, r, t)

                        new_row = {'S0':s0, 'K':k, 'V0':v0, 'T':t, 'V0': v0, 'r':r, 'n':nn, 'm':mm, 'closed_solution':sol, 'mc_price':mc_price, 'ST':ST}
                        #append row to the dataframe
                        df = df.append(new_row, ignore_index=True)

# %%
df.head()

# %%
df.to_csv("solution_complete_mc.csv")

# %%
def plot_mc (s,T,n, m):
    # Setup figure
    plt.figure(figsize=(8,6))
    # noinspection PyTypeChecker
    ax_lines = plt.axes()

    maxx = np.max(s)
    minn = np.min(s)

    # Make the line plots
    t = np.linspace(0, T, num = n + 1)
    ns = 40
    for i in range(ns):
        ax_lines.plot(t, s[i, :], lw=1.0)
    ax_lines.set(xlabel='Years', ylabel='St',title='Price Simulations')
    ax_lines.set_xlim((0, T))
    ax_lines.set_ylim((minn, maxx))

    # Add mean value to line plots
    ax_lines.plot([0.0, 1.0], [s[:, -1].mean(), s[:, -1].mean()], lw='2', ls="--", label='mean')
    plt.show()

    # plot stock prices distributions
    plt.figure(figsize=(6,5))
    bins = np.arange(1.4, 3, .04)
    plt.hist(s[:, -1], bins=bins)
    plt.xlabel('ST')
    plt.ylabel('Number')
    plt.title('Stock Prices distribution')
    plt.show()

# %%
stock_v01_1.size
# Out:
# 15687500

# %%
plot_mc (stock_v01_1, 1, n[0], m[0])

# %%
#%lprun -f stock_price_generator stock_price_generator(t, n, m, r, s0, k, v0, sigma, theta, kappa, rho, generator) # stock prices of mc simulation

# %%
solution_mc = pd.read_csv('solution_complete_mc.csv')
solution_mc.head()
# Out:
#    Unnamed: 0  S0    K    V0  T     r    n       m  closed_solution  mc_price  \
# 0           0   2  1.5  0.01  1  0.00  250   62500         0.501704  0.504032
# 1           1   2  1.5  0.01  1  0.00  400  160000         0.501704  0.505141
# 2           2   2  1.5  0.01  1  0.05  250   62500         0.605693  0.576967
# 3           3   2  1.5  0.01  1  0.05  400  160000         0.605693  0.575875
# 4           4   2  1.5  0.01  2  0.00  250   62500         0.644682  0.518217
#
#                                                   ST
# 0  [2.14920711 1.73480919 2.17702466 ... 2.078845...
# 1  [2.03162331 1.78371728 1.24721405 ... 2.159474...
# 2  [1.85020765 2.35377389 1.52989921 ... 2.510885...
# 3  [2.21679141 1.3781657  1.88192877 ... 2.107734...
# 4  [1.62136112 1.99737066 1.52279903 ... 1.699463...

# %% [markdown]
# # AV

# %%
def stock_price_generator_av (T, n ,m, r, S0, k, V0, sigma, theta, kappa, rho, separate=False):
    dt = T / n
    
    m = int(m/2) # with av we can do half of the simulations
    
    # Brownian motions:
    dw_v = generator.normal(size=(m, n)) * np.sqrt(dt)
    dw_i = generator.normal(size=(m, n)) * np.sqrt(dt)

    dw_s = rho * dw_v + np.sqrt(1.0 - rho ** 2) * dw_i

    # Perform time evolution 
    s = np.empty((m, n + 1)) # initialisation stock prices vector
    s[:, 0] = S0
    
    s_ant = np.empty((m, n + 1))
    s_ant[:, 0] = S0

    v = np.ones(m) * V0
    v_ant = np.ones(m) * V0

    for t in range(n):
        dv = kappa * (theta - v) * dt + sigma * np.sqrt(v) * dw_v[:, t]
        dv_ant = kappa * (theta - v_ant) * dt + sigma * np.sqrt(v_ant) * dw_v[:, t]
        ds = r * s[:, t] * dt + np.sqrt(v) * s[:, t] * dw_s[:, t]
        ds_ant = r * s_ant[:, t] * dt + np.sqrt(v_ant) * s_ant[:, t] * dw_s[:, t]

        v = np.clip(v + dv, a_min=0.0, a_max=None)
        v_ant = np.clip(v_ant + dv_ant, a_min=0.0, a_max=None)
        
        s[:, t + 1] = s[:, t] + ds
        s_ant[:, t + 1] = s_ant[:, t] + ds_ant
        
    if separate==True:
        return s, s_ant
        
    return np.concatenate((s, s_ant))

# %%
mc_price_av = []
ST_av = []

for row in solution_mc.index:
    T = solution_mc['T'][row]
    n = solution_mc['n'][row]
    m = solution_mc['m'][row]
    r = solution_mc['r'][row]
    S0 = solution_mc['S0'][row]
    K = solution_mc['K'][row]
    V0 = solution_mc['V0'][row]
    
    s_ant = stock_price_generator_av (T, n, m, r, S0, K, V0, sigma, theta, kappa, rho)
    ST = s_ant[:,-1]
    
    ST_av.append(ST)
    mc_price_av.append(find_expected_payoff(ST, K, r, T))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-372378bac5b5> in <module>
#      11     V0 = solution_mc['V0'][row]
#      12
# ---> 13     s_ant = stock_price_generator_av (T, n, m, r, S0, K, V0, sigma, theta, kappa, rho)
#      14     ST = s_ant[:,-1]
#      15
#
# <ipython-input-23-b1d1006ed8de> in stock_price_generator_av(T, n, m, r, S0, k, V0, sigma, theta, kappa, rho, separate)
#       5
#       6     # Brownian motions:
# ----> 7     dw_v = generator.normal(size=(m, n)) * np.sqrt(dt)
#       8     dw_i = generator.normal(size=(m, n)) * np.sqrt(dt)
#       9
#
# KeyboardInterrupt:

# %%
solution_complete_mc['mc_price_av'] = mc_price_av
solution_complete_mc['ST_av'] = ST_av

# %%
row('T')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-38309b0e3f55> in <module>
# ----> 1 row('T')
#
# TypeError: 'tuple' object is not callable

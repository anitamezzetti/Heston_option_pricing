# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from matplotlib import pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv("dataset2.csv")
df = df.drop('Unnamed: 0', axis=1)

df.head()
# Out:
#       price     stock  strike  maturity  initial_vol  interest_rates
# 0  0.187565  2.012875     1.6       1.0         0.01             0.0
# 1  0.234718  1.979601     1.6       1.0         0.01             0.0
# 2  0.190948  2.011839     1.6       1.0         0.01             0.0
# 3  0.275900  2.012831     1.6       1.0         0.01             0.0
# 4  0.017349  2.019834     1.6       1.0         0.01             0.0

# %% [markdown]
# ## Classification

# %%
df['exercise'] = df.price!=0
df = df.drop(['price', 'interest_rates'], axis=1)
df.head()
# Out:
#       stock  strike  maturity  initial_vol  exercise
# 0  2.012875     1.6       1.0         0.01      True
# 1  1.979601     1.6       1.0         0.01      True
# 2  2.011839     1.6       1.0         0.01      True
# 3  2.012831     1.6       1.0         0.01      True
# 4  2.019834     1.6       1.0         0.01      True

# %%
df.groupby('exercise').count().stock
# Out:
# exercise
# False     82088
# True     157912
# Name: stock, dtype: int64

# %%
table = pd.crosstab(df.strike, df.exercise)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart depending on the strike')
plt.xlabel('K')
plt.ylabel('Proportion')
plt.savefig('e_vs_ne_strike')

# %%
table = pd.crosstab(df.initial_vol, df.exercise)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart depending on the initial vol')
plt.xlabel('initial_vol')
plt.ylabel('Proportion')
plt.savefig('e_vs_ne_initial_vole')

# %%
table = pd.crosstab(df.maturity, df.exercise)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart depending on the maturity')
plt.xlabel('T')
plt.ylabel('Proportion')
plt.savefig('e_vs_ne_strike')

# %%
# plot function confusion matrix

from sklearn.metrics import confusion_matrix
def plot_confusion_matrix (confusion_matrix, title):

    ax = plt.subplot()
    sns.heatmap(confusion_matrix,annot=True,fmt = "d",square = True,ax = ax, linewidths = 1, linecolor = "w", cmap = "Pastel2")
    ax.set_xlabel('True labels')
    ax.set_ylabel('Predicted labels')
    ax.xaxis.set_ticklabels(['Exercised','Not Exercised'])
    ax.yaxis.set_ticklabels(['Exercised','Not Exercised'], va="center")
    plt.title(title)
    plt.show()

# %%
# plot function roc curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

def plot_roc_curve(X_test, y_test, y_pred, model, title):
    logit_roc_auc = roc_auc_score(y_test, y_pred)
    fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
    plt.figure()
    plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    titlee = 'Exercise ROC curve ' + title
    plt.title(titlee)
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()

# %%
X = df.drop('exercise', axis = 1)
y = df['exercise']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_logistic = logreg.predict(X_test)

# %%
confusion_matrix_logistic = confusion_matrix(y_test, y_pred_logistic, labels=[True, False])
plot_confusion_matrix (confusion_matrix_logistic, 'Logistic Regression')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_logistic))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.59      0.41      0.48     16412
#         True       0.74      0.85      0.79     31588
#
#     accuracy                           0.70     48000
#    macro avg       0.66      0.63      0.64     48000
# weighted avg       0.68      0.70      0.68     48000

# %%
print('Accuracy logistic regression classifier: {:.2f}%'.format(logreg.score(X_test, y_test)*100))
# Out:
# Accuracy logistic regression classifier: 69.95%

# %%
plot_roc_curve(X_test, y_test, y_pred, logreg, 'Logistic Reg')

# %% [markdown]
# ## KNN

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier

Neighbor_List=[3,5,10,20]
parameters = {'n_neighbors':Neighbor_List}
KNNC = KNeighborsClassifier()
classifier_knn = GridSearchCV(KNNC, parameters, cv=5, verbose=0, scoring ='accuracy')

classifier_knn.fit(X_train, y_train)
y_pred = classifier_knn.predict(X_test)

# %%
print('Accuracy KNN: {:.2f}%'.format(logreg.score(X_test, y_test)*100))
# Out:
# Accuracy KNN: 69.85%

# %%
confusion_matrix_knn = confusion_matrix(y_test, y_pred, labels=[True, False])
plot_confusion_matrix (confusion_matrix_knn, 'KNN')

# %%
plot_roc_curve(X_test, y_test, y_pred, classifier_knn, 'KNN')

# %% [markdown]
# ## XGBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from xgboost import XGBClassifier

params = {
    'n_estimators': [100, 200, 400],
    'max_depth': [2, 3, 6],
    'learning_rate': [0.005, 0.01, 0.02],
    'subsample': [0.4, 0.8]
}
classifier_xgboost = GridSearchCV(XGBClassifier(random_state=10), params, scoring ='accuracy')
classifier_xgboost.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=10, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.005, 0.01, 0.02],
#                          'max_depth': [2, 3, 6],
#                          'n_estimators': [100, 200, 400],
#                          'subsample': [0.4, 0.8]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
y_pred = classifier_xgboost.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy XGBoost: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy XGBoost: 69.97%

# %%
confusion_matrix_knn = confusion_matrix(y_test, y_pred, labels=[True, False])
plot_confusion_matrix (confusion_matrix_knn, 'XGBoost')

# %%
plot_roc_curve(X_test, y_test, y_pred, classifier_xgboost, 'XGBoost')

# %%
# feature importance

clf= XGBClassifier(learning_rate= 0.005, max_depth= 2, n_estimators= 100, subsample= 0.6,random_state=10)
clf.fit(X_train, y_train)
features = X.columns
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

plt.barh(X.columns, clf.feature_importances_)
plt.show()
# Out:
# Feature ranking:
# 1. feature 1 (0.818041)
# 2. feature 0 (0.181959)
# 3. feature 3 (0.000000)
# 4. feature 2 (0.000000)

# %% [markdown]
# ## Neural Networkzzzzz

# %%
def print_accuracy(train_metric, val_metric):
    # summarize history for loss
    plt.plot(train_metric)
    plt.plot(val_metric)
    plt.plot([0, len(train_metric)], [0.5, 0.5], '--', color='black', alpha=0.7)
    plt.title('Model AUC progress')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.ylim(ymax = 1, ymin = 0)
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
epoch_num = 30

# %%
from keras.metrics import BinaryAccuracy, AUC, Precision, Recall
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History
from keras.optimizers import Adam

# 1 hidden layer
model = Sequential()
model.add(Dense(20, input_dim=X.shape[1], activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(lr=1e-2),
              loss='binary_crossentropy',
              metrics=[BinaryAccuracy(), AUC(), Precision(), Recall()])

# %%
history = model.fit(X, y, epochs=epoch_num, validation_split=0.2, batch_size=128, callbacks=[History()])
# Out:
# Epoch 1/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.5640 - binary_accuracy: 0.7104 - auc_5: 0.7083 - precision_5: 0.7374 - recall_5: 0.8979 - val_loss: 0.6595 - val_binary_accuracy: 0.6035 - val_auc_5: 0.6630 - val_precision_5: 0.6870 - val_recall_5: 0.4990
# Epoch 2/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5561 - binary_accuracy: 0.7169 - auc_5: 0.7197 - precision_5: 0.7452 - recall_5: 0.8927 - val_loss: 0.6482 - val_binary_accuracy: 0.6230 - val_auc_5: 0.6647 - val_precision_5: 0.6248 - val_recall_5: 0.7699
# Epoch 3/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5549 - binary_accuracy: 0.7167 - auc_5: 0.7215 - precision_5: 0.7463 - recall_5: 0.8896 - val_loss: 0.6510 - val_binary_accuracy: 0.6210 - val_auc_5: 0.6645 - val_precision_5: 0.6161 - val_recall_5: 0.8061
# Epoch 4/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5553 - binary_accuracy: 0.7159 - auc_5: 0.7210 - precision_5: 0.7451 - recall_5: 0.8908 - val_loss: 0.6490 - val_binary_accuracy: 0.6235 - val_auc_5: 0.6644 - val_precision_5: 0.6268 - val_recall_5: 0.7622
# Epoch 5/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5546 - binary_accuracy: 0.7168 - auc_5: 0.7220 - precision_5: 0.7461 - recall_5: 0.8903 - val_loss: 0.6482 - val_binary_accuracy: 0.6224 - val_auc_5: 0.6648 - val_precision_5: 0.6203 - val_recall_5: 0.7898
# Epoch 6/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5544 - binary_accuracy: 0.7171 - auc_5: 0.7222 - precision_5: 0.7459 - recall_5: 0.8914 - val_loss: 0.6476 - val_binary_accuracy: 0.6235 - val_auc_5: 0.6648 - val_precision_5: 0.6425 - val_recall_5: 0.6955
# Epoch 7/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5547 - binary_accuracy: 0.7173 - auc_5: 0.7219 - precision_5: 0.7467 - recall_5: 0.8901 - val_loss: 0.6552 - val_binary_accuracy: 0.6132 - val_auc_5: 0.6648 - val_precision_5: 0.6002 - val_recall_5: 0.8672
# Epoch 8/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5542 - binary_accuracy: 0.7169 - auc_5: 0.7224 - precision_5: 0.7462 - recall_5: 0.8904 - val_loss: 0.6540 - val_binary_accuracy: 0.6127 - val_auc_5: 0.6643 - val_precision_5: 0.6738 - val_recall_5: 0.5594
# Epoch 9/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5544 - binary_accuracy: 0.7178 - auc_5: 0.7219 - precision_5: 0.7454 - recall_5: 0.8942 - val_loss: 0.6470 - val_binary_accuracy: 0.6244 - val_auc_5: 0.6650 - val_precision_5: 0.6291 - val_recall_5: 0.7557
# Epoch 10/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5539 - binary_accuracy: 0.7176 - auc_5: 0.7230 - precision_5: 0.7447 - recall_5: 0.8954 - val_loss: 0.6571 - val_binary_accuracy: 0.6048 - val_auc_5: 0.6651 - val_precision_5: 0.5904 - val_recall_5: 0.8954
# Epoch 11/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5543 - binary_accuracy: 0.7177 - auc_5: 0.7223 - precision_5: 0.7465 - recall_5: 0.8913 - val_loss: 0.6469 - val_binary_accuracy: 0.6250 - val_auc_5: 0.6645 - val_precision_5: 0.6329 - val_recall_5: 0.7410
# Epoch 12/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5540 - binary_accuracy: 0.7170 - auc_5: 0.7228 - precision_5: 0.7471 - recall_5: 0.8883 - val_loss: 0.6489 - val_binary_accuracy: 0.6211 - val_auc_5: 0.6642 - val_precision_5: 0.6201 - val_recall_5: 0.7851
# Epoch 13/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5542 - binary_accuracy: 0.7174 - auc_5: 0.7224 - precision_5: 0.7479 - recall_5: 0.8874 - val_loss: 0.6649 - val_binary_accuracy: 0.6057 - val_auc_5: 0.6650 - val_precision_5: 0.5912 - val_recall_5: 0.8942
# Epoch 14/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5540 - binary_accuracy: 0.7175 - auc_5: 0.7227 - precision_5: 0.7480 - recall_5: 0.8873 - val_loss: 0.6487 - val_binary_accuracy: 0.6220 - val_auc_5: 0.6649 - val_precision_5: 0.6190 - val_recall_5: 0.7949
# Epoch 15/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5538 - binary_accuracy: 0.7179 - auc_5: 0.7230 - precision_5: 0.7486 - recall_5: 0.8869 - val_loss: 0.6474 - val_binary_accuracy: 0.6246 - val_auc_5: 0.6647 - val_precision_5: 0.6352 - val_recall_5: 0.7294
# Epoch 16/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5537 - binary_accuracy: 0.7174 - auc_5: 0.7232 - precision_5: 0.7476 - recall_5: 0.8880 - val_loss: 0.6491 - val_binary_accuracy: 0.6191 - val_auc_5: 0.6649 - val_precision_5: 0.6590 - val_recall_5: 0.6223
# Epoch 17/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5537 - binary_accuracy: 0.7183 - auc_5: 0.7232 - precision_5: 0.7491 - recall_5: 0.8863 - val_loss: 0.6469 - val_binary_accuracy: 0.6221 - val_auc_5: 0.6648 - val_precision_5: 0.6457 - val_recall_5: 0.6778
# Epoch 18/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5537 - binary_accuracy: 0.7184 - auc_5: 0.7232 - precision_5: 0.7484 - recall_5: 0.8882 - val_loss: 0.6481 - val_binary_accuracy: 0.6248 - val_auc_5: 0.6646 - val_precision_5: 0.6291 - val_recall_5: 0.7569
# Epoch 19/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7175 - auc_5: 0.7233 - precision_5: 0.7470 - recall_5: 0.8897 - val_loss: 0.6476 - val_binary_accuracy: 0.6241 - val_auc_5: 0.6646 - val_precision_5: 0.6260 - val_recall_5: 0.7692
# Epoch 20/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5538 - binary_accuracy: 0.7178 - auc_5: 0.7229 - precision_5: 0.7475 - recall_5: 0.8892 - val_loss: 0.6475 - val_binary_accuracy: 0.6240 - val_auc_5: 0.6649 - val_precision_5: 0.6427 - val_recall_5: 0.6966
# Epoch 21/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7177 - auc_5: 0.7233 - precision_5: 0.7479 - recall_5: 0.8881 - val_loss: 0.6492 - val_binary_accuracy: 0.6235 - val_auc_5: 0.6645 - val_precision_5: 0.6290 - val_recall_5: 0.7516
# Epoch 22/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5535 - binary_accuracy: 0.7182 - auc_5: 0.7235 - precision_5: 0.7483 - recall_5: 0.8881 - val_loss: 0.6477 - val_binary_accuracy: 0.6228 - val_auc_5: 0.6645 - val_precision_5: 0.6238 - val_recall_5: 0.7740
# Epoch 23/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5534 - binary_accuracy: 0.7178 - auc_5: 0.7236 - precision_5: 0.7477 - recall_5: 0.8886 - val_loss: 0.6484 - val_binary_accuracy: 0.6225 - val_auc_5: 0.6641 - val_precision_5: 0.6240 - val_recall_5: 0.7714
# Epoch 24/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7178 - auc_5: 0.7233 - precision_5: 0.7479 - recall_5: 0.8883 - val_loss: 0.6478 - val_binary_accuracy: 0.6211 - val_auc_5: 0.6645 - val_precision_5: 0.6508 - val_recall_5: 0.6561
# Epoch 25/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7178 - auc_5: 0.7233 - precision_5: 0.7481 - recall_5: 0.8878 - val_loss: 0.6469 - val_binary_accuracy: 0.6218 - val_auc_5: 0.6647 - val_precision_5: 0.6468 - val_recall_5: 0.6726
# Epoch 26/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5537 - binary_accuracy: 0.7182 - auc_5: 0.7231 - precision_5: 0.7483 - recall_5: 0.8883 - val_loss: 0.6489 - val_binary_accuracy: 0.6233 - val_auc_5: 0.6647 - val_precision_5: 0.6456 - val_recall_5: 0.6833
# Epoch 27/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5538 - binary_accuracy: 0.7179 - auc_5: 0.7231 - precision_5: 0.7473 - recall_5: 0.8899 - val_loss: 0.6501 - val_binary_accuracy: 0.6191 - val_auc_5: 0.6641 - val_precision_5: 0.6565 - val_recall_5: 0.6302
# Epoch 28/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7180 - auc_5: 0.7232 - precision_5: 0.7461 - recall_5: 0.8930 - val_loss: 0.6509 - val_binary_accuracy: 0.6218 - val_auc_5: 0.6637 - val_precision_5: 0.6463 - val_recall_5: 0.6741
# Epoch 29/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5538 - binary_accuracy: 0.7175 - auc_5: 0.7231 - precision_5: 0.7441 - recall_5: 0.8969 - val_loss: 0.6468 - val_binary_accuracy: 0.6237 - val_auc_5: 0.6650 - val_precision_5: 0.6283 - val_recall_5: 0.7561
# Epoch 30/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5535 - binary_accuracy: 0.7177 - auc_5: 0.7235 - precision_5: 0.7457 - recall_5: 0.8934 - val_loss: 0.6484 - val_binary_accuracy: 0.6215 - val_auc_5: 0.6648 - val_precision_5: 0.6163 - val_recall_5: 0.8077

# %%
print_accuracy( history.history['auc'], history.history['val_auc'])

# %%
# 1 wider hidden layer
wider_model = Sequential()
wider_model.add(Dense(20, input_dim=X.shape[1], activation='relu'))
wider_model.add(Dense(40, activation='relu'))
wider_model.add(Dense(1, activation='sigmoid'))

wider_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[BinaryAccuracy(), AUC(), Precision(), Recall()])

# %%
history_wider = wider_model.fit(X, y, epochs=30, validation_split=0.2, batch_size=128)
# Out:
# Epoch 1/30
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.5627 - binary_accuracy: 0.7113 - auc_1: 0.7094 - precision_1: 0.7338 - recall_1: 0.9093 - val_loss: 0.6490 - val_binary_accuracy: 0.6228 - val_auc_1: 0.6645 - val_precision_1: 0.6217 - val_recall_1: 0.7844
# Epoch 2/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5534 - binary_accuracy: 0.7177 - auc_1: 0.7236 - precision_1: 0.7476 - recall_1: 0.8888 - val_loss: 0.6468 - val_binary_accuracy: 0.6246 - val_auc_1: 0.6644 - val_precision_1: 0.6414 - val_recall_1: 0.7040
# Epoch 3/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5531 - binary_accuracy: 0.7185 - auc_1: 0.7240 - precision_1: 0.7478 - recall_1: 0.8901 - val_loss: 0.6487 - val_binary_accuracy: 0.6236 - val_auc_1: 0.6641 - val_precision_1: 0.6224 - val_recall_1: 0.7847
# Epoch 4/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7179 - auc_1: 0.7240 - precision_1: 0.7478 - recall_1: 0.8886 - val_loss: 0.6594 - val_binary_accuracy: 0.6124 - val_auc_1: 0.6649 - val_precision_1: 0.5998 - val_recall_1: 0.8657
# Epoch 5/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5529 - binary_accuracy: 0.7181 - auc_1: 0.7242 - precision_1: 0.7479 - recall_1: 0.8889 - val_loss: 0.6488 - val_binary_accuracy: 0.6224 - val_auc_1: 0.6649 - val_precision_1: 0.6192 - val_recall_1: 0.7959
# Epoch 6/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5531 - binary_accuracy: 0.7179 - auc_1: 0.7239 - precision_1: 0.7471 - recall_1: 0.8905 - val_loss: 0.6469 - val_binary_accuracy: 0.6253 - val_auc_1: 0.6650 - val_precision_1: 0.6309 - val_recall_1: 0.7510
# Epoch 7/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5529 - binary_accuracy: 0.7178 - auc_1: 0.7241 - precision_1: 0.7475 - recall_1: 0.8893 - val_loss: 0.6487 - val_binary_accuracy: 0.6225 - val_auc_1: 0.6648 - val_precision_1: 0.6213 - val_recall_1: 0.7852
# Epoch 8/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5529 - binary_accuracy: 0.7183 - auc_1: 0.7241 - precision_1: 0.7475 - recall_1: 0.8902 - val_loss: 0.6510 - val_binary_accuracy: 0.6212 - val_auc_1: 0.6636 - val_precision_1: 0.6161 - val_recall_1: 0.8069
# Epoch 9/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5528 - binary_accuracy: 0.7179 - auc_1: 0.7243 - precision_1: 0.7476 - recall_1: 0.8893 - val_loss: 0.6468 - val_binary_accuracy: 0.6248 - val_auc_1: 0.6652 - val_precision_1: 0.6297 - val_recall_1: 0.7544
# Epoch 10/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7183 - auc_1: 0.7246 - precision_1: 0.7477 - recall_1: 0.8897 - val_loss: 0.6465 - val_binary_accuracy: 0.6243 - val_auc_1: 0.6651 - val_precision_1: 0.6421 - val_recall_1: 0.7001
# Epoch 11/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5525 - binary_accuracy: 0.7182 - auc_1: 0.7247 - precision_1: 0.7476 - recall_1: 0.8897 - val_loss: 0.6485 - val_binary_accuracy: 0.6199 - val_auc_1: 0.6646 - val_precision_1: 0.6516 - val_recall_1: 0.6488
# Epoch 12/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7180 - auc_1: 0.7246 - precision_1: 0.7473 - recall_1: 0.8901 - val_loss: 0.6467 - val_binary_accuracy: 0.6235 - val_auc_1: 0.6647 - val_precision_1: 0.6385 - val_recall_1: 0.7110
# Epoch 13/30
# 1490/1500 [============================>.] - ETA: 0s - loss: 0.5524 - binary_accuracy: 0.7187 - auc_1: 0.7249 - precision_1: 0.7482 - recall_1: 0.8896
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-048d9f9a762e> in <module>
# ----> 1 history_wider = wider_model.fit(X, y, epochs=30, validation_split=0.2, batch_size=128)
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1121                 model=self,
#    1122                 steps_per_execution=self._steps_per_execution)
# -> 1123           val_logs = self.evaluate(
#    1124               x=val_x,
#    1125               y=val_y,
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\miniconda3\envs\fbd\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print_accuracy(history_wider.history['auc_8'], history_wider.history['val_auc_8'])

# %%
# deeper model
deeper_model = Sequential()
deeper_model.add(Dense(20, input_dim=X.shape[1], activation='relu'))
deeper_model.add(Dense(20, activation='relu'))
deeper_model.add(Dense(20, activation='relu'))
deeper_model.add(Dense(1, activation='sigmoid'))

deeper_model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = [BinaryAccuracy(), AUC(), Precision(), Recall()])

# %%
deeper_history = model.fit(X, y, epochs=epoch_num, validation_split=0.2, batch_size=128)
# Out:
# Epoch 1/30
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.5608 - binary_accuracy: 0.7125 - auc_7: 0.7121 - precision_7: 0.7365 - recall_7: 0.9048 - val_loss: 0.6483 - val_binary_accuracy: 0.6226 - val_auc_7: 0.6642 - val_precision_7: 0.6420 - val_recall_7: 0.6933
# Epoch 2/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5536 - binary_accuracy: 0.7180 - auc_7: 0.7234 - precision_7: 0.7485 - recall_7: 0.8873 - val_loss: 0.6512 - val_binary_accuracy: 0.6214 - val_auc_7: 0.6649 - val_precision_7: 0.6158 - val_recall_7: 0.8098
# Epoch 3/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5538 - binary_accuracy: 0.7183 - auc_7: 0.7231 - precision_7: 0.7482 - recall_7: 0.8888 - val_loss: 0.6497 - val_binary_accuracy: 0.6219 - val_auc_7: 0.6648 - val_precision_7: 0.6198 - val_recall_7: 0.7903
# Epoch 4/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5535 - binary_accuracy: 0.7177 - auc_7: 0.7234 - precision_7: 0.7479 - recall_7: 0.8880 - val_loss: 0.6475 - val_binary_accuracy: 0.6239 - val_auc_7: 0.6644 - val_precision_7: 0.6298 - val_recall_7: 0.7499
# Epoch 5/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5535 - binary_accuracy: 0.7179 - auc_7: 0.7235 - precision_7: 0.7478 - recall_7: 0.8888 - val_loss: 0.6473 - val_binary_accuracy: 0.6232 - val_auc_7: 0.6641 - val_precision_7: 0.6370 - val_recall_7: 0.7158
# Epoch 6/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5533 - binary_accuracy: 0.7180 - auc_7: 0.7237 - precision_7: 0.7477 - recall_7: 0.8893 - val_loss: 0.6476 - val_binary_accuracy: 0.6244 - val_auc_7: 0.6653 - val_precision_7: 0.6282 - val_recall_7: 0.7598
# Epoch 7/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7182 - auc_7: 0.7241 - precision_7: 0.7473 - recall_7: 0.8905 - val_loss: 0.6559 - val_binary_accuracy: 0.6117 - val_auc_7: 0.6649 - val_precision_7: 0.6765 - val_recall_7: 0.5496
# Epoch 8/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5531 - binary_accuracy: 0.7182 - auc_7: 0.7240 - precision_7: 0.7478 - recall_7: 0.8894 - val_loss: 0.6472 - val_binary_accuracy: 0.6225 - val_auc_7: 0.6645 - val_precision_7: 0.6445 - val_recall_7: 0.6837
# Epoch 9/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5531 - binary_accuracy: 0.7177 - auc_7: 0.7239 - precision_7: 0.7473 - recall_7: 0.8895 - val_loss: 0.6479 - val_binary_accuracy: 0.6231 - val_auc_7: 0.6652 - val_precision_7: 0.6228 - val_recall_7: 0.7805
# Epoch 10/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5531 - binary_accuracy: 0.7183 - auc_7: 0.7240 - precision_7: 0.7478 - recall_7: 0.8896 - val_loss: 0.6479 - val_binary_accuracy: 0.6227 - val_auc_7: 0.6651 - val_precision_7: 0.6227 - val_recall_7: 0.7792
# Epoch 11/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7182 - auc_7: 0.7241 - precision_7: 0.7475 - recall_7: 0.8900 - val_loss: 0.6472 - val_binary_accuracy: 0.6220 - val_auc_7: 0.6652 - val_precision_7: 0.6473 - val_recall_7: 0.6717
# Epoch 12/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7173 - auc_7: 0.7241 - precision_7: 0.7472 - recall_7: 0.8887 - val_loss: 0.6473 - val_binary_accuracy: 0.6243 - val_auc_7: 0.6650 - val_precision_7: 0.6271 - val_recall_7: 0.7645
# Epoch 13/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5528 - binary_accuracy: 0.7180 - auc_7: 0.7244 - precision_7: 0.7474 - recall_7: 0.8900 - val_loss: 0.6482 - val_binary_accuracy: 0.6223 - val_auc_7: 0.6641 - val_precision_7: 0.6483 - val_recall_7: 0.6693
# Epoch 14/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7181 - auc_7: 0.7241 - precision_7: 0.7473 - recall_7: 0.8903 - val_loss: 0.6471 - val_binary_accuracy: 0.6221 - val_auc_7: 0.6650 - val_precision_7: 0.6449 - val_recall_7: 0.6806
# Epoch 15/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5528 - binary_accuracy: 0.7181 - auc_7: 0.7244 - precision_7: 0.7474 - recall_7: 0.8902 - val_loss: 0.6467 - val_binary_accuracy: 0.6232 - val_auc_7: 0.6652 - val_precision_7: 0.6418 - val_recall_7: 0.6970
# Epoch 16/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5530 - binary_accuracy: 0.7179 - auc_7: 0.7241 - precision_7: 0.7474 - recall_7: 0.8895 - val_loss: 0.6471 - val_binary_accuracy: 0.6243 - val_auc_7: 0.6649 - val_precision_7: 0.6277 - val_recall_7: 0.7616
# Epoch 17/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5528 - binary_accuracy: 0.7178 - auc_7: 0.7243 - precision_7: 0.7470 - recall_7: 0.8903 - val_loss: 0.6474 - val_binary_accuracy: 0.6230 - val_auc_7: 0.6642 - val_precision_7: 0.6453 - val_recall_7: 0.6830
# Epoch 18/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7186 - auc_7: 0.7247 - precision_7: 0.7474 - recall_7: 0.8912 - val_loss: 0.6475 - val_binary_accuracy: 0.6219 - val_auc_7: 0.6652 - val_precision_7: 0.6487 - val_recall_7: 0.6662
# Epoch 19/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5527 - binary_accuracy: 0.7178 - auc_7: 0.7245 - precision_7: 0.7471 - recall_7: 0.8902 - val_loss: 0.6480 - val_binary_accuracy: 0.6219 - val_auc_7: 0.6651 - val_precision_7: 0.6225 - val_recall_7: 0.7763
# Epoch 20/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5525 - binary_accuracy: 0.7187 - auc_7: 0.7247 - precision_7: 0.7471 - recall_7: 0.8922 - val_loss: 0.6516 - val_binary_accuracy: 0.6169 - val_auc_7: 0.6648 - val_precision_7: 0.6641 - val_recall_7: 0.5993
# Epoch 21/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5527 - binary_accuracy: 0.7188 - auc_7: 0.7245 - precision_7: 0.7473 - recall_7: 0.8918 - val_loss: 0.6486 - val_binary_accuracy: 0.6215 - val_auc_7: 0.6650 - val_precision_7: 0.6534 - val_recall_7: 0.6493
# Epoch 22/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5527 - binary_accuracy: 0.7180 - auc_7: 0.7245 - precision_7: 0.7465 - recall_7: 0.8921 - val_loss: 0.6480 - val_binary_accuracy: 0.6221 - val_auc_7: 0.6652 - val_precision_7: 0.6197 - val_recall_7: 0.7917
# Epoch 23/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5525 - binary_accuracy: 0.7182 - auc_7: 0.7247 - precision_7: 0.7466 - recall_7: 0.8923 - val_loss: 0.6512 - val_binary_accuracy: 0.6174 - val_auc_7: 0.6643 - val_precision_7: 0.6609 - val_recall_7: 0.6106
# Epoch 24/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7183 - auc_7: 0.7246 - precision_7: 0.7474 - recall_7: 0.8907 - val_loss: 0.6500 - val_binary_accuracy: 0.6180 - val_auc_7: 0.6648 - val_precision_7: 0.6586 - val_recall_7: 0.6194
# Epoch 25/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7181 - auc_7: 0.7246 - precision_7: 0.7466 - recall_7: 0.8920 - val_loss: 0.6468 - val_binary_accuracy: 0.6235 - val_auc_7: 0.6652 - val_precision_7: 0.6251 - val_recall_7: 0.7707
# Epoch 26/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5527 - binary_accuracy: 0.7177 - auc_7: 0.7244 - precision_7: 0.7458 - recall_7: 0.8931 - val_loss: 0.6483 - val_binary_accuracy: 0.6229 - val_auc_7: 0.6652 - val_precision_7: 0.6205 - val_recall_7: 0.7912
# Epoch 27/30
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5524 - binary_accuracy: 0.7185 - auc_7: 0.7249 - precision_7: 0.7475 - recall_7: 0.8907 - val_loss: 0.6471 - val_binary_accuracy: 0.6241 - val_auc_7: 0.6647 - val_precision_7: 0.6245 - val_recall_7: 0.7765
# Epoch 28/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5526 - binary_accuracy: 0.7178 - auc_7: 0.7244 - precision_7: 0.7462 - recall_7: 0.8923 - val_loss: 0.6462 - val_binary_accuracy: 0.6240 - val_auc_7: 0.6651 - val_precision_7: 0.6369 - val_recall_7: 0.7195
# Epoch 29/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5525 - binary_accuracy: 0.7185 - auc_7: 0.7247 - precision_7: 0.7470 - recall_7: 0.8921 - val_loss: 0.6466 - val_binary_accuracy: 0.6241 - val_auc_7: 0.6652 - val_precision_7: 0.6281 - val_recall_7: 0.7589
# Epoch 30/30
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5525 - binary_accuracy: 0.7187 - auc_7: 0.7247 - precision_7: 0.7472 - recall_7: 0.8918 - val_loss: 0.6472 - val_binary_accuracy: 0.6230 - val_auc_7: 0.6651 - val_precision_7: 0.6221 - val_recall_7: 0.7836

# %%
print_accuracy(history_deeper, epoch_num)

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'auc_5', 'precision_5', 'recall_5', 'val_loss', 'val_binary_accuracy', 'val_auc_5', 'val_precision_5', 'val_recall_5'])
